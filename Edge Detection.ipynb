# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

imagename = '/Users/ridakhan/Desktop/Uni/cardetection/customImages/train/image3.jpg'

# %% [markdown]
# # EDGE DETECTION

# %%
img = cv.imread(imagename, 0) 

"""First argument is our input image. Second and third arguments are our minVal and maxVal respectively. 
Third argument is aperture_size. It is the size of Sobel kernel used for find image gradients. 
By default it is 3. Last argument is L2gradient which specifies the equation for finding gradient magnitude. 
If it is True, it uses the equation mentioned above which is more accurate"""

edges = cv.Canny(img,255, 255) #input image, minVal, maxVal 

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
#Just edge detection

import cv2

# this function is needed for the createTrackbar step downstream
def nothing(x):
    pass

imagename = '/Users/ridakhan/Desktop/car1.jpg'
# read the experimental image
img = cv2.imread(imagename, 0)

# create trackbar for canny edge detection threshold changes
cv2.namedWindow('canny')

# add ON/OFF switch to "canny"
switch = '0 : OFF \n1 : ON'
cv2.createTrackbar(switch, 'canny', 0, 1, nothing)

# add lower and upper threshold slidebars to "canny"
cv2.createTrackbar('lower', 'canny', 0, 255, nothing)
cv2.createTrackbar('upper', 'canny', 0, 255, nothing)

# Infinite loop until we hit the escape key on keyboard
while(1):

    # get current positions of four trackbars
    lower = cv2.getTrackbarPos('lower', 'canny')
    upper = cv2.getTrackbarPos('upper', 'canny')
    s = cv2.getTrackbarPos(switch, 'canny')

    if s == 0:
        edges = img
    else:
        edges = cv2.Canny(img, lower, upper)

    # display images
    cv2.imshow('original', img)
    cv2.imshow('canny', edges)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:   # hit escape to quit
        break

cv2.destroyAllWindows()

# %% [markdown]
# # BLURRING

# %%
import skimage
import sys

img = cv.imread(imagename, 0) 
sigma = 3.0
edges = cv.Canny(img,255, 255) #input image, minVal, maxVal 

blurred = skimage.filters.gaussian(
    edges, sigma=(sigma, sigma), truncate=3.5, multichannel=True)

plt.imshow(blurred,cmap = 'gray')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

img = cv.imread(imagename) 
blur = cv.medianBlur(img ,3)
edges = cv.Canny(blur, 255, 255)

plt.imshow(edges, cmap = 'gray')
plt.show()

# %% [markdown]
# # BLUR THEN EDGE

# %%
#First Try with bilateralFilter(img,9, 150, 150)

import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

imagename = '/Users/ridakhan/Desktop/Uni/cardetection/customImages/train/image3.jpg'

import cv2

def nothing(x):
    pass

img = cv2.imread(imagename) 
blur = cv2.bilateralFilter(img,9, 150, 150)
# create trackbar for canny edge detection threshold changes
cv2.namedWindow('canny')

# add ON/OFF switch to "canny"
switch = '0 : OFF \n1 : ON'
cv2.createTrackbar(switch, 'canny', 0, 1, nothing)

# add lower and upper threshold slidebars to "canny"
cv2.createTrackbar('lower', 'canny', 0, 255, nothing)
cv2.createTrackbar('upper', 'canny', 0, 255, nothing)

# Infinite loop until we hit the escape key on keyboard
while(1):

    # get current positions of four trackbars
    lower = cv2.getTrackbarPos('lower', 'canny')
    upper = cv2.getTrackbarPos('upper', 'canny')
    s = cv2.getTrackbarPos(switch, 'canny')

    if s == 0:
        edges = blur
    else:
        edges = cv2.Canny(blur, lower, upper)

    # display images
    cv2.imshow('original', img)
    cv2.imshow('canny', edges)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:   # hit escape to quit
        break

cv2.destroyAllWindows()

# %%
#Saving all edge/ blur images in folder

import os
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image

for filename in os.listdir('/Users/ridakhan/Desktop/Uni/cardetection/customImages/train/'):
    print(filename)
    img = cv2.imread('/Users/ridakhan/Desktop/Uni/cardetection/customImages/train/'+filename) 
    blur = cv2.bilateralFilter(img,9, 200, 200)
    edges = cv2.Canny(blur, 105, 200)
    cv2.imwrite('/Users/ridakhan/Desktop/Uni/cardetection/customImages/edges/'+filename.split('.')[0]+'.png',edges)
    #print(filename.split('.')[0])

plt.imshow(edges, cmap = 'gray')
plt.show()
# Out:
# image63.jpg
# image89.jpg
# image62.jpg
# image18.jpeg
# image60.jpg
# image48.jpg
# image49.jpg
# image61.jpg
# image55.jpeg
# image8.jpg
# image59.png
# .DS_Store
# image71.jpg
# image65.jpg
# image64.jpg
# image70.jpg
# image58.jpg
# image19.jpeg
# image1.jpeg
# image66.jpg
# image72.jpg
# image73.jpg
# image67.jpg
# imagetraing4.jpeg
# image14.jpg
# image28.jpg
# image90.jpeg
# image15.jpg
# imagetraing8.png
# image17.jpg
# image16.jpg
# image13.jpg
# image39.jpg
# image10.jpg
# image38.jpg
# imagetraing1.jpg
# imagetraing3.jpg
# imagetraing2.jpg
# imagetraing6.jpg
# image33.jpg
# image5.jpeg
# imagetraing7.png
# imagetraing5.jpg
# image9.jpeg
# image46.jpeg
# image7.jpg
# image42.jpg
# image56.jpg
# image57.jpg
# image43.jpg
# image6.png
# image4.jpg
# image82.jpg
# image54.jpg
# image78.jpg
# image50.jpg
# image44.jpg
# image86.jpg
# image45.jpg
# image51.png
# image40.jpeg
# image2.jpg
# image21.jpeg
# image47.jpg
# image53.jpg
# image85.jpg
# image52.jpg
# image3.jpg

# %%
#THIS ONE WORKS with bilateralFilter(img,9, 200, 200)

import numpy as np
from matplotlib import pyplot as plt

imagename = '/Users/ridakhan/Desktop/Uni/cardetection/customImages/train/image4.jpg'

import cv2

def nothing(x):
    pass

img = cv2.imread(imagename) 
blur = cv2.bilateralFilter(img,9, 200, 200)
# create trackbar for canny edge detection threshold changes
cv2.namedWindow('canny')

# add ON/OFF switch to "canny"
switch = '0 : OFF \n1 : ON'
cv2.createTrackbar(switch, 'canny', 0, 1, nothing)

# add lower and upper threshold slidebars to "canny"
cv2.createTrackbar('lower', 'canny', 0, 255, nothing)
cv2.createTrackbar('upper', 'canny', 0, 255, nothing)

# Infinite loop until we hit the escape key on keyboard
while(1):

    # get current positions of four trackbars
    lower = cv2.getTrackbarPos('lower', 'canny')
    upper = cv2.getTrackbarPos('upper', 'canny')
    s = cv2.getTrackbarPos(switch, 'canny')

    if s == 0:
        edges = blur
    else:
        edges = cv2.Canny(blur, lower, upper)

    # display images
    cv2.imshow('original', img)
    cv2.imshow('canny', edges)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:   # hit escape to quit
        break

cv2.destroyAllWindows()

# %% [markdown]
# # CONTOUR TRIALS, NOT CURRENTLY WORKING

# %%
#TRIED CONTOURS

import numpy as np
import cv2

im = cv2.imread(imagename)
imCopy = im.copy()

imgray=cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)

ret,thresh = cv2.threshold(imgray,127,255,0)

image, contours, hierarchy =  cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

cv2.drawContours(imCopy,contours,-1,(0,255,0))
cv2.imshow('draw contours',imCopy)
cv2.waitKey(0)

# %%
import numpy as np
import cv2

im = cv2.imread(imagename)
edges = cv.Canny(im,100,200) #input image, minVal, maxVal 

image, contours, hierarchy =  cv2.findContours(edges,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

cv2.drawContours(im, contours, -1, (0,255,0), 3)
cv2.imshow('draw contours', im)
cv2.waitKey(0)

# %%
import cv2

# this function is needed for the createTrackbar step downstream
def nothing(x):
    pass

# read the experimental image
img = cv2.imread(imagename, 0)
imCopy = img.copy()

# create trackbar for canny edge detection threshold changes
cv2.namedWindow('canny')

# add ON/OFF switch to "canny"
switch = '0 : OFF \n1 : ON'
cv2.createTrackbar(switch, 'canny', 0, 1, nothing)

# add lower and upper threshold slidebars to "canny"
cv2.createTrackbar('lower', 'canny', 0, 255, nothing)
cv2.createTrackbar('upper', 'canny', 0, 255, nothing)

# Infinite loop until we hit the escape key on keyboard
while(1):

    # get current positions of four trackbars
    lower = cv2.getTrackbarPos('lower', 'canny')
    upper = cv2.getTrackbarPos('upper', 'canny')
    s = cv2.getTrackbarPos(switch, 'canny')

    if s == 0:
        edges = img
    else:
        edges = cv2.Canny(img, lower, upper)
        image, contours, hierarchy =  cv2.findContours(edges,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
        cv2.drawContours(imCopy,contours,-1,(0,255,0))

    # display images
    cv2.imshow('original', img)
    cv2.imshow('canny', imCopy)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:   # hit escape to quit
        break

cv2.destroyAllWindows()
